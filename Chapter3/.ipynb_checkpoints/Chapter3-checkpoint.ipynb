# %%
# Importing libraries
library(MASS)
library(ISLR)

# %% [markdown]
# #### **Simple Linear Regression**

# %%
# Boston dataset
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio black
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
names(Boston)
# Out:
#  [1] "crim"    "zn"      "indus"   "chas"    "nox"     "rm"      "age"
#  [8] "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"   "medv"

# %%
?Boston

# %%
#  The basic syntax is lm(y∼x,data), where y is the response, x is the predictor, and
# data is the data set in which these two variables are kept

# %%
lm.fit = lm(medv ~ lstat, data=Boston)

# %%
attach(Boston)

# %%
lm.fit = lm(medv ~ lstat)

# %%
lm.fit
# Out:
# Call:
# lm(formula = medv ~ lstat)
#
# Coefficients:
# (Intercept)        lstat
#       34.55        -0.95

# %%
summary(lm.fit)
# Out:
# Call:
# lm(formula = medv ~ lstat)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -15.168  -3.990  -1.318   2.034  24.500
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 34.55384    0.56263   61.41   <2e-16 ***
# lstat       -0.95005    0.03873  -24.53   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 6.216 on 504 degrees of freedom
# Multiple R-squared:  0.5441,	Adjusted R-squared:  0.5432
# F-statistic: 601.6 on 1 and 504 DF,  p-value: < 2.2e-16

# %%
names(lm.fit)
# Out:
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"

# %%
# Coefficients
coef(lm.fit)
# Out:
# (Intercept)       lstat
#  34.5538409  -0.9500494

# %%
# Confidence Intervals
confint(lm.fit)
# Out:
#             2.5 %     97.5 %
# (Intercept) 33.448457 35.6592247
# lstat       -1.026148 -0.8739505

# %%
predict(lm.fit, data.frame(lstat=c(5, 10, 15)), interval='confidence')
# Out:
#   fit      lwr      upr
# 1 29.80359 29.00741 30.59978
# 2 25.05335 24.47413 25.63256
# 3 20.30310 19.73159 20.87461

# %%
predict(lm.fit, data.frame(lstat=c(5, 10, 15)), interval='prediction')
# Out:
#   fit      lwr       upr
# 1 29.80359 17.565675 42.04151
# 2 25.05335 12.827626 37.27907
# 3 20.30310  8.077742 32.52846

# %%
plot(lstat, medv, pch='+')
abline(lm.fit, lwd=3, col='red')
# Out:
# plot without title

# %%
# par(mfrow=c(2,2))
plot(lm.fit)
# Inference, the first plot tells that there is a non linear relationship in the data.
# If it were a straight line, it would have been a perfectly linear fit
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
plot(predict(lm.fit), residuals(lm.fit))
# Out:
# plot without title

# %%
plot(predict(lm.fit), rstudent(lm.fit))
# Out:
# plot without title

# %%
plot(hatvalues(lm.fit))
# Leverage values
# Out:
# plot without title

# %%
which.max(hatvalues(lm.fit)) # returns the index of point with max leverage
# Out:
# 375
# 375
